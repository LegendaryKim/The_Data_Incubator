# %% [markdown]
# ## Q3. Capstone Project

# %% [markdown]
# The weather and temporal relationships on NYC yellow taxi demands and duration
#
# Weather conditions impact on traffic conditions intensively and also change the needs of taxi. Furthermore, the temporal states are highly related to the demands of taxi. With the taxi demands, the taxi duration also effects on the income of the taxi corps. Based on the open data of the yellow taxi and the temporal weather data in NYC in 2010-2017, I will explore the influences of the two factors on the taxi demands. The result will suggest the best temporal/spatial recommendations for taxi drivers to find taxi users frequently according to the current conditions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
YellowTaxi_Data = pd.read_csv('./yellow_tripdata_2016-01.csv')
Weather_Data = pd.read_csv('./weather_data_nyc_centralpark_2016(1).csv')

# %%
YellowTaxi_Data
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 1                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 2                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 3                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 4                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 5                2  2016-01-01 00:00:00   2016-01-01 00:18:30
# 6                2  2016-01-01 00:00:00   2016-01-01 00:26:45
# 7                1  2016-01-01 00:00:01   2016-01-01 00:11:55
# 8                1  2016-01-01 00:00:02   2016-01-01 00:11:14
# 9                2  2016-01-01 00:00:02   2016-01-01 00:11:08
# 10               2  2016-01-01 00:00:03   2016-01-01 00:06:19
# 11               2  2016-01-01 00:00:03   2016-01-01 00:15:49
# 12               2  2016-01-01 00:00:03   2016-01-01 00:00:11
# 13               1  2016-01-01 00:00:04   2016-01-01 00:14:32
# ...

# %%
Weather_Data
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# 5      6-1-2016                   41                   25
# 6      7-1-2016                   46                   31
# 7      8-1-2016                   46                   31
# 8      9-1-2016                   47                   40
# 9     10-1-2016                   59                   40
# 10    11-1-2016                   40                   26
# 11    12-1-2016                   44                   25
# 12    13-1-2016                   30                   22
# 13    14-1-2016                   38                   22
# 14    15-1-2016                   51                   34
# ...

# %%
YellowTaxi_datetime = pd.to_datetime(YellowTaxi_Data['tpep_pickup_datetime'].dropna(), format='%Y-%m-%d %H:%M:%S')

# %%
Weather_datetime = pd.to_datetime(Weather_Data['date'].dropna())

# %%
Weather_datetime.apply(lambda x: x.month).value_counts()
# Out:
# 12    31
# 10    31
# 8     31
# 7     31
# 5     31
# 3     31
# 1     31
# 11    30
# 9     30
# 6     30
# 4     30
# 2     29
# Name: date, dtype: int64

# %%
Weather_datetime_averagetemp = Weather_Data[['date', 'average temperature']]

# %%
Weather_datetime_averagetemp
# Out:
#            date  average temperature
# 0      1-1-2016                 38.0
# 1      2-1-2016                 36.0
# 2      3-1-2016                 40.0
# 3      4-1-2016                 25.0
# 4      5-1-2016                 20.0
# 5      6-1-2016                 33.0
# 6      7-1-2016                 38.5
# 7      8-1-2016                 38.5
# 8      9-1-2016                 43.5
# 9     10-1-2016                 49.5
# 10    11-1-2016                 33.0
# 11    12-1-2016                 34.5
# 12    13-1-2016                 26.0
# 13    14-1-2016                 30.0
# 14    15-1-2016                 42.5
# 15    16-1-2016                 47.0
# 16    17-1-2016                 36.0
# 17    18-1-2016                 24.5
# 18    19-1-2016                 22.0
# 19    20-1-2016                 32.0
# 20    21-1-2016                 31.0
# 21    22-1-2016                 25.5
# 22    23-1-2016                 25.5
# 23    24-1-2016                 27.5
# ...

# %%
plt.plot(Weather_datetime_averagetemp['average temperature'])
plt.show()
